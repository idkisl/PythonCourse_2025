# %% [markdown]
# # Семинар 2. Коллекции

# %% [markdown]
# Семинар собран Иваном Кисляковым. Разрешено к использованию в некоммерческих образовательных целях с указанием авторства.
#
# Вопросы и замечания можно отправлять по адресу mipt-dpo@yandex.ru

# %% [markdown]
# ## Шаг 0.
#
# Скачайте на свой компьютер jupyter notebook. Войдите в аккаунт Google и посмотрите на работу Google Collab.
# Скачайте среду разработки PyCharm Community.
#
# На данном семинаре рекомендовано использовать как среду разработки, так и jupyter notebook.

# %% [markdown]
# ## Коллекция список

# %% [markdown]
# #### Задание 1
# 1. Вводится с экрана 10 чисел. Запишите их в список, а затем выведите список на экран.
# 2. Вводится с экрана чисела, пока не будет введен нуль. Запишите в список те из них, которые кратны 13, а затем выведите список на экран.

# %%
# 1.1

# 1.2

# %% [markdown]
# #### Задание 2
# Дан список чисел. Если в нем есть два соседних элемента одного знака, выведите эти числа. Если соседних элементов одного знака нет - не выводите ничего. Если таких пар соседей несколько - выведите первую пару.

# %%
# 2

# %% [markdown]
# #### Задание 3
# Дан список чисел. Определите, сколько в этом списке элементов, которые больше двух своих соседей и выведите количество таких элементов.

# %%
# 3

# %% [markdown]
# #### Задание 4
# Дан список чисел. Выведите значение наибольшего элемента в списке, а затем индекс этого элемента в списке. Если наибольших элементов несколько, выведите индекс первого из них.

# %%
# 4

# %% [markdown]
# #### Задание 5
# Выведите значение наименьшего из всех положительных элементов в списке. Известно, что в списке есть хотя бы один положительный элемент, а значения всех элементов списка по модулю не превосходят 1000.

# %%
# 5

# %% [markdown]
# #### Задание 6
# Имеется два списка разной длины. Необходимо создать третий, состоящий из всех элемнтов списка. При этом элементы не могут повторяться (если в итоговом списке уже есть такой элемент, добавлять его второй раз не надо).

# %%
# 6

# %% [markdown]
# #### Задание 7
# Дан список из чисел и индекс (k) элемента в списке. Удалите из списка элемент с индексом k, сдвинув влево все элементы, стоящие правее элемента с индексом k.

# %%
# 7

# %% [markdown]
# ## Коллекция строка

# %% [markdown]
# #### Задание 8
# 1. Определите, являктся ли введенный символ буквой?
# 2. Определите, являктся ли введенный символ цифрой?
# 3. Определите, являктся ли введенная буква буквой из русского алфавита?
# 4. Дано название города. Определить, четно или нет количество символов в нем.
# 5. Определите, правда ли первая и последняя буква слова имеют одинаковый регистр (обе большие или обе маленькие).

# %%
# 8.1

# %%
# 8.2

# %%
# 8.3

# %%
# 8.4

# %%
# 8.5

# %% [markdown]
# #### Задание 9
# 1. Из слова трос путем "вырезок" и "склеек" его букв получить слова сорт, рост и торс.
# 2. Из слова "строка" путем замены его букв получить слово "строфа".

# %%
# 9.1

# %%
# 9.2

# %% [markdown]
# #### Задание 10
# 1. Даны два слова. Верно ли, что первое слово начинается на ту же букву, на которую заканчивается второе слово.
# 2. Дано название футбольного клуба. Напечатать его на экране "столбиком".
# 3. Составить программу, которая печатает введенное слово, начиная с последней буквы.
# 3. Проверьте, что введенное слово является палиндромом (читается слева-направо также как и справа-налево)
# 4. Дано предложение. Определить, сколько в нем гласных букв.

# %%
# 10.1

# %%
# 10.2

# %%
# 10.3

# %%
# 10.4

# %% [markdown]
# ## Коллекция множество

# %% [markdown]
# #### Задание 11
# 1. Создайте пустое множество. И добавьте в него названия трех своих самых любимых продуктов.
# 2. Создайте множество из букв строки. На экран выведите количество использованных символов в строке.
# 3. Вводится две фамилии. Определите те буквы, которые встречаются хотя бы в одной из фамилий и выведите их на экран.
# 4. Вводится два имени. Определите те буквы, которые встречаются в обоих именах и выведите их на экран.
# 5. Вводится две строчки текста. Определете те символы, которые встречаются лишь в одной из строчек. Выведите их количество на экран.

# %%
# 11.1

# %%
# 11.2

# %%
# 11.3

# %%
# 11.4

# %%
# 11.5

# %% [markdown]
# ## Использование коллекций

# %% [markdown]
# #### Задание 12
# 1. Вводятся числа, пока не будет введено число -10. Далее пользователь вводит цифру K. На экран выведите те из них, которые оканчиваются на цифру K, которую ввел пользователь.
# 2. Вводятся строчки, пока не введена пустая строчка. Далее вводится слово-маяк. На экран выведите те строчки, в которых присутствовало это слово-маяк.
# 3. Дано предложение. В нем слова разделены одним пробелом (начальные и конечные пробелы и символ "-" в предложении отсутствуют). Определить количество слов в предложении.

# %%
# 12.1

# %%
# 12.2

# %%
# 12.3

# %% [markdown]
# #### Задание 13 (методы списков и строк)
# 1. С помощью списочного выражения создайте список на 15 элементов, состоящего из квадратов четных чисел больших 45.
# 2. Вводятся имена студентов группы через пробел. Выведите их же, но через дефис.
# 3. Вводятся числа через пробел. Выведите их же, но через двоеточие.
# 4. Вводится текст, предложения разделены точками. Выведите на экран второе предложение.
# 5. Вводится предложение, слова в котором разделены пробелами. Найдите количество слов в предложении.

# %%
# 13.1

# %%
# 13.2

# %%
# 13.3

# %%
# 13.4

# %%
# 13.5

# %% [markdown]
# #### Задание 14  (методы списков и строк)
# 1. Вводится текст, в котором между словами стоят пробелы. Определите, какая первая буква в пятом введенном слове?
# 2. Найдите сумму соседних элементов (первый и последний элементы соседствуют друг с другом) и выведите полученные суммы через дефис на экран.
# 3. Вводятся целые числа через пробел. Найдите минимальное среди них и положите на 0-ой индекс в список.

# %%
# 14.1

# %%
# 14.2

# %%
# 14.3

# %% [markdown]
# ## Коллекция словарь

# %% [markdown]
# #### Задание 15
# Создайте таблицу перевода чисел с помощью транслитерации. Переведите введенное слово по правилам транслитерации.

# %%
# 15

# %% [markdown]
# #### Задание 16
# Вводтся пары значений. Имена людей и их возраст. Среди людей, в имени которых есть буква 'a' найдите самого старшего и выведите его на эран.

# %%
# 16

# %% [markdown]
# #### Задание 17
# Напишите программу, которая принимает на вход строку, и выводит слово, которое встречается во фразе реже всего. Если редких слов несколько, нужно вывести то, которое меньше в лексикографическом порядке. Регистр слов не учитывается, знаки препинания в предложениях игнорируются.

# %%
# 17

# %% [markdown]
# #### Задание 18
# Дан словарь, в котором в качестве ключей хранятся имена клиентов банка, а в качестве значений -- сумма на счете.
# 1. Узнайте количество клиентов в банке?
# 2. Узнайте суммарное колличество денег, хранящееся в банке?
# 3. Выведите имена тех клиентов, сумма на счетах которых превышает 20000.

# %%
# 18.1

# 18.2

# 18.3

# %% [markdown]
# #### Задание 19
# Молодой бизнессмен хранит данные записной книжки в формате фамилия - номер телефона.
#
# Но периодическии номера меняются, тогда программе приходит запрос вида change surname:new_telephone_number
#
# Или бизнессмен прекращает свое общение с партнером, тогда приходит запрос вида forget surname
#
# Или бизнессмен узнает номер нового партнера new_number surname:new_telephone_number
#
# Обработайте N запросов к телефонной книге

# %%
# 19

# %% [markdown]
# #### Задание 20
# Даны два списка одинаковой длины. Необходимо создать из них словарь таким образом, чтобы элементы первого списка были ключами, а элементы второго — соответственно значениями нашего словаря.

# %%
# 20
