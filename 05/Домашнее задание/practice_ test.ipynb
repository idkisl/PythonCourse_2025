# %% [markdown]
# # Лабораторная работа по изучению файлов

# %% [markdown]
# Лабораторная работа собрана Иваном Кисляковым. Разрешено к использованию в некоммерческих образовательных целях с указанием авторства.
#
# Вопросы и замечания можно отправлять по адресу mipt-dpo@yandex.ru

# %% [markdown]
# ## Исключения

# %% [markdown]
# #### Задание 1
# Напишите функцию sum_line(line), принимающую на вход строку, содержащую в себе числа, записанные через пробел. Функция возвращает сумму этих чисел. В случае, если функция вызвана с неправильным аргументом, необходимо характеризовать ошибку и вывести сообщение о ней на экран.
# ```
# Пример 1: sum_line("1 2 3 4") -> 10
# Привер 2: sum_line("mipt 1 2 3") -> "Неверный формат чисел в строке"
# Привер 3: sum_line("1.2 2.4 5.1") -> 8.7
# Привер 4: sum_line("1, 2, 3") -> "Неверный формат чисел в строке"
# ```

# %% [markdown]
# #### Задание 2
# Напишите функцию ```win_lottery(ticket)```, принимающую на вход шестизначное число - номер билета. Если билет является числом палиндромом, он является призовым. Если сумма цифр на нечетных позициях равна сумме цифр на четных позициях, он - выигрышный.
#
# По введенной строке ticket определите, является ли билет выигрышным или призовым - функция возвращает строчку с сообщением вердикта. Если в билете присутствуют посторонние символы, вызывается исключение ```TypeError```, если это не шестизначное число, вызывается исключение ```ValueErrorr```.

# %% [markdown]
# #### Задание 3
# Напишите функцию ```participation_in_lottery()```. Внутри функции считывается одно значение - номер билета (в строковом формате). Далее вызывается функция ```win_lottery(ticket)``` из предыдущего номера. Если функция вернула значение призер / победитель / обычный билет - такие результаты выводятся на экран. Если же функция вернула исклчение:
# 1. Если исключение произошло из-за неверного числа, необходимо вывести сообщение о неверном номере на экран и завершить выполнении функции.
# 2. Если исключение произошло из-за неверных символов в билете, необходимо вызвать исключение ```RuntimeError```.

# %% [markdown]
# #### Задание 4
# Студенты заполняли форму, в которой указывали свои номера телефонов в формате ```+7(985)123-45-67```. Деканату необходимо составить списки студентов в формате ```+79851234567``` для удобства. Напишите функцию, выполняющую задачу при условии, что студенты могли ошибаться в заполнении формы, указывать номер не в том формате. Тогда необходимо вызвать исключение ValueError.
#
# Ошибками может быть:
# 1. Нет скобок вокруг кода оператора.
# 2. Неверное количество цифр в номере.
# 3. В номере присутствуют посторонние символы.
# 4. Формат записи не соответствует заявленному (нет дифисов в нужных местах, нет +7 в начале, нет скобок)

# %% [markdown]
# #### Задание 5
# Напишите функцию ```check_password(input_password)```, которая бы проверяла, что введенный пароль является "mipt_1234_all_good". Если введен неверный пароль, программа завершает свою работу с ошибкой.
#
# Важно! Программа должна занимать не более двух строчек, из которой одна - объявление функции.

# %% [markdown]
# #### Задание 6
# Создайте набор собственных исключений для проверки сложности пароля. Да-да именно такой достаточно раздражающий интерфейс Вы напишете.
#
# 1. Если пароль слишком короткий, вызывается ошибка ```SmallLenghtError```.
# 2. Если пароль слишком длинный, вызывается ошибка ```BigLenghtError```.
# 3. Если в пароле нет цифр, вызывается ошибка ```NoDigitsError```.
# 4. Если в пароле нет специальных символов, вызывается ошибка ```NoSpecialSymbolError```.
#
# Напишите функцию ```check_new_password(password)``` проверки корректности нового пароля.

# %%
# функция проверки пароля на соответствие требованиям и вызов соответственных ошибок при наличии некорректности

# %% [markdown]
# ## UnitTest

# %% [markdown]
# #### Задание 7
# Напишите, используя UnitTest или PyTest, тесты проверяющие корректность (в нашем случае - некоррестность) выполнения функции:
# ```
# def hash_function(a, b, size):
#     return ((a + b) ** 0.5 / b) % size
# ```
# Понятное дело, данная функция будет иногда некорректно работать. Перепишите ее так, чтобы при возникновении ошибки функция вызывала собственное исключение с пояснениями.

# %%
# новая версия hash_function

# %% [markdown]
# #### Задание 8
# Напишите, используя модуль UnitTest, проверку функции bubble_sort, приведенной ниже. Обязательно выполните проверку следующих ситуаций:
# 0. Корректность сортировки
# 1. Пустой список
# 2. Список одинаковых элементов
# 3. Список строчек
# 4. Список с нулем
# 5. Список с разными типами данных (необходимо, чтобы функция вызывала исключение ```TypeError```)
#
# ```
# def bubbleSort(array):
#     for i in range(len(array)):
#         for j in range(0, len(array) - i - 1):
#             if compare(array[j], array[j + 1]):
#                 temp = array[j]
#                 array[j] = array[j + 1]
#                 array[j + 1] = temp
# ```

# %% [markdown]
# #### Задание 9
# Напишите, используя модуль PyTest, проверку ```check_new_password(password)```. Рассмотрите все возможные случаи.
