# %% [markdown]
# # Лабораторная работа по изучению pandas

# %% [markdown]
# Лабораторная работа собрана Иваном Кисляковым. Разрешено к использованию в некоммерческих образовательных целях с указанием авторства.
#
# Вопросы и замечания можно отправлять по адресу mipt-dpo@yandex.ru

# %% [markdown]
# #### Задание 1
# Создайте HTTP запрос к ```https://catfact.ninja/#/``` и получите 5 различных пород кошек.

# %%
# 1
# Ваш HTTP-запрос вставьте сюда

# %% [markdown]
# #### Задание 2
# 1. Зарегистрируйтесь на [сайте](https://openweathermap.org/current) и получите API KEY.
# 2. Найдите информацию о погоде в центре Москвы в текущий момент времени. Получите информацию с помощью модуля requests.
# 3. На экран выведите: температуру в цельсиях, название города, уровень над морем, температуру в цельсиях на которую ощущается погода.

# %%
# 2.1

# 2.2

# 2.3

# %% [markdown]
# #### Задание 3
# 1. Воспользуйтесь ```https://api.github.com/users/{username}``` API github для получений информации о пользователе matheusfelipeog.
# 2. На экран выведите информацию о его имени, bio, дату создания профиля на Git.

# %%
# 3

# %% [markdown]
# #### Задание 4
# 1. Вопользуйтесь Static API Яндекс Карт для получения информации о своем городе.
# 2. Постройте маршрут на карте (по координатам) от своего дома до института.
# 3. Изображение сохраните в файле или выведите на экран.

# %%
# 4

# %% [markdown]
# #### Задание 5
# 1. Воспользуйтесь [GeoCoder](https://yandex.ru/maps-api/docs/geocoder-api/quickstart.html) для получения информации об объектах по определенному адресу или координатам.
# 2. Найдите и выведите на экран координаты ```ул. Льва Толстого, 16, Москва```
# 3. Найдите и выведите на экран информацию адрес по координатам ```37.520653,55.929182```

# %%
# 5

# %% [markdown]
# #### Задание 6
# Создайте UDP-сервер, который получает текстовые сообщения и возвращает их обратно, переворачивая буквы в каждом слове.
# ```
# output client: Hello world python
# input client: olleH dlrow nohtyp
# ```

# %%
# 6
