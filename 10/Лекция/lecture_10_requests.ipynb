# %% [markdown]
# ## Лекция 10
# ### Модуль requests, HTTP, socket
#
# Лекция прочитана Иваном Кисляковым. Разрешено к использованию в некоммерческих образовательных целях.

# %% [markdown]
# ## Работа с HTTP запросами

# %%
import requests

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'JSONDecodeError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet_version',
#  'charset_normalizer_version',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
# ...

# %%
help(requests.get)
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
response = requests.get("https://old.mipt.ru/")
print(response)
# Out:
# <Response [200]>

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response.headers
# Out:
# {'Server': 'nginx', 'Date': 'Wed, 12 Nov 2025 06:48:05 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'P3P': 'policyref="/bitrix/p3p.xml", CP="NON DSP COR CUR ADM DEV PSA PSD OUR UNR BUS UNI COM NAV INT DEM STA"', 'Set-Cookie': 'PHPSESSID=b0laa3r5mcq5bvbp04hh38lr85; path=/; HttpOnly', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Pragma': 'no-cache', 'X-Frame-Options': 'SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip'}

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="ru">\r\n<head>\r\n<title>МФТИ — Московский физико-технический институт</title>\r\n<meta name="title" content="МФТИ">\r\n<script src="/js/vue/dist/vue.min.js"></script>\r\n<script src="/js/jquery.min.js"></script>\r\n<script src="/js/jquery-ui-1.8.20.custom.min.js"></script>\r\n<script src="/bitrix/templates/.default/script.js"></script>\r\n<script src="/bitrix/templates/.default/js/portal.js"></script>\r\n<script src="/bitrix/templates/.default/js/main.js"></script>\r\n<script src="/bitrix/templates/.default/js/slider.js"></script>\r\n<script src="/bitrix/templates/.default/js/jquery.hoverIntent.js"></script>\r\n<script src="/bitrix/templates/.default/js/jquery.autoellipsis.min.js"></script>\r\n<script src="/js/canvasjs.min.js"></script>\r\n<script src="/js/jadditional.js"></script>\r\n<script src="/js/lang.js"></script>\r\n<script src="/bitrix/templates/.default/js/social-likes.min.js"></script>\r\n<script src="//yastatic.net/browser-updater/v1/script
# ...

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## API

# %% [markdown]
# '+' клиента
# 1. Сохранение ресурсов (переложили ответственность)
# 2. Использование готовых решений
# 3. API вместо модуля: обновление информации
#
# '+' сервера
# 1. Реклама системы
# 2. Денюжки зарабатываем
# 3. Интегированная реклама

# %%
requests.get("https://static-maps.yandex.ru/v1?ll=37.648297,55.753636&lang=ru_RU&z=17&maptype=transit&apikey=...")
# Out:
# <Response [200]>

# %%
print(help(requests.get))
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response
#
# None

# %%
url = "https://static-maps.yandex.ru/v1"
params = {"ll": "37.648297,55.753636",
         "lang": "ru_RU",
         "apikey": "..."}
requests.get(url, params=params)
# Out:
# <Response [200]>
