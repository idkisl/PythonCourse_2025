# %% [markdown]
# # Семинар 10. Модуль requests
#
# Семинар собран Иваном Кисляковым. Разрешено к использованию в некоммерческих образовательных целях с указанием авторства.
#
# Вопросы и замечания можно отправлять по адресу mipt-dpo@yandex.ru

# %% [markdown]
# ## Работа с HTTP запросами

# %% [markdown]
# #### Задание 1
# Изучите [документацию](https://yandex.ru/maps-api/docs/static-api/index.html) yandex maps. [Получите](https://developer.tech.yandex.ru/) API_KEY в кабинете разработчика.
#
# Формат запроса:
# ```py
# https://static-maps.yandex.ru/v1
#   ? apikey=<string>
#   & ll=<float,float>
#   & [spn=<float>]
#   & [bbox=<float,float~float,float>]
#   & [z=<integer>]
#   & [size=<integer,integer>]
#   & [scale=<float>]
#   & [pt=<string>]
#   & [pl=<string>]
#   & [lang=<string>]
#   & [style=<string>]
#   & [theme=<string>]
#   & [maptype=<string>]
# ```

# %% [markdown]
# #### Задание 2
# В браузере пошлите http-запрос вида ```https://static-maps.yandex.ru/v1?ll=37.518310,55.929456&z=16&apikey=API_KEY```

# %% [markdown]
# #### Задание 3
# Найдите на карте координаты своего дома и получите изображение на карте.

# %% [markdown]
# #### Задание 4
# 1. Найдите на карте координаты своего дома и получите изображение на карте.
# 2. Найдите на карте координаты своего ВУЗа и получите изображение на карте.
# 3. Найдите главное здание МГУ и как бы оно выглядело на англоязычных картах со спутника.
# 4. Найдите библиотеку имени Ленина и выведите изображение карты размера 500 на 500 пикселей.

# %% [markdown]
# #### Задание 5
# Впишите ```https://static-maps.yandex.ru/v1?ll=37.518310,55.929456&z=16&apikey=API_KEY``` запрос в браузер Google Chome и нажмите клавишу F12 и войдите в раздел network. Посмотрите на структуру HTTP - ответа.
#
# Измените запрос так, чтобы получить различные коды возврата:
# - 200
# - 304
# - 403
# - 400
#
# Описание кодов возврата можно посмотреть [здесь](https://ru.wikipedia.org/wiki/HTTP)

# %% [markdown]
# #### Задание 6
# Зайдите на [сайт](https://www.weather.gov/documentation/services-web-api) и получите информацию в аэропорту города Майями.

# %% [markdown]
# #### Задание 7
# Импортируйте модуль requestst. Совершите get-запрос с помощью модуля к сайту ```https://mipt.ru```
# Выведите на экран
# 1. Доступные атрибуты с помощью команды dir
# 2. headers
# 3. text
# 4. status_code
#
# По полученным данным выясните, кто делал дизайн сайта.
#
# ```py
# import requests
# response = requests.get(<адрес>)
# ```

# %% [markdown]
# #### Задание 8
# Воспользуйтесь обращением к сайту ```https://catfact.ninja/fact``` и выведите случайный факт о кошке длиной сообщения не более 45 символов.

# %% [markdown]
# #### Задание 9
# 1. Зарегистрируйтесь на [сайте](https://currency.getgeoapi.com) для получения API_KEY к конвертеру валют.
# 2. Зайдите в раздел документации и ознакомьитесь с возможностями данного ресурса.
# 3. После получения ключа API получите GET запросом json с курсами валют ```https://api.getgeoapi.com/v2/currency/convert?api_key=API_KEY```
# 4. После получения данных определите курс Russian ruble по отношению к Norwegian krone

# %% [markdown]
# #### Задание 10
# 1. Воспользуйстесь Static API Яндекс.Карт
# 2. Воспользуйтесь словарем params для передачи аргументов через requests.
# 3. Создайте приложение, которое получает координаты (как при копировании из яндекс-карт - перевернутые) и по ним строит изображение на карте.
# 4. Размер изображения 450 на 450
# 5. Коэффициент приближения 9
# 6. Карта снятая со спутника.

# %% [markdown]
# ## Работа с Socket

# %% [markdown]
# #### Задание 11
# 1. Создай UDP ЭХО-сервер на socket
# 2. Протестируй подключение клиента к выбранному серверу.

# %%
# 11.1

# %%
# 11.2

# %% [markdown]
# #### Задание 12
# Создайте TCP сервер, который возвращает текущее время в формате MM:HH::SS. Для получения времени воспользуйтесь модулем [time](https://docs.python.org/3/library/time.html)

# %% [markdown]
# #### Задание 13
# Создайте простейший мессенджер двух пользователей, использовав UDP сервер. Сообщения передаются от первого подключившегося ко второму и наоборот.
